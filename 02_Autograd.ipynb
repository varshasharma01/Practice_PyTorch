# %% [markdown]
# <a href="https://colab.research.google.com/github/varshasharma01/Practice_PyTorch/blob/main/02_Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import math

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
def dy_dx(x):
  return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
z = math.sin(y)
# Out:
# /tmp/ipykernel_5987/4100833346.py:1: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   z = math.sin(y)

# %%
z
# Out:
# -0.7568024953079282

# %%
def dz_dx(x):
  return 2*x * (math.cos(x**2))

# %%
dz_dx(3.0)
# Out:
# -5.466781571308061

# %%
x = torch.tensor(3.0, requires_grad=True)
y = x**2
z = torch.sin(y)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z.grad
# Out:
# /tmp/ipykernel_5987/4110045842.py:1: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:492.)
#   z.grad

# %%
# z and y are non leaf , these are calculated internally in computational graph so the grad can't be calculated for z and y

# %%
y.grad
# Out:
# /tmp/ipykernel_5987/486760323.py:1: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:492.)
#   y.grad

# %% [markdown]
# **Calculate Loss**

# %%
x = torch.tensor(6.7) #this tensor contains 6.7 cgpa
y = torch.tensor(0.0) #this tensor contains true label

# %%
x
# Out:
# tensor(6.7000)

# %%
y
# Out:
# tensor(0.)

# %%
w = torch.tensor(1.0)
